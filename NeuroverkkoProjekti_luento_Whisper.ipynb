# %% [markdown]
# Puheentunnistus Whisper kirjastolla

# %%
import torch
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# Set the audio filename - update this to your actual filename
audio_file = "Kokeilu_1.wav"

# pip install transformers

# äänien lataus
# pip install librosa
# puhe kannattaa tallentaa monona whisper tykkää 16khz näytetaajuus
# äänen taajuus (korkeus) määrittää mikä sample rate kannattaa olla, pitäisi olla 2xfrequency

# hieno loading screen thingy
# pip install ipywidgets

# pip install PySoundFile
# conda install -c conda-forge libsndfile
# pip install sentencepiece
# pip install sacremoses

# fourier muunnos:
# mikä tahansa funktio voidaan esittää sin-aaltojen muotoisena.
# mikä tahansa aaltomuoto voidaan esittää eri kokoisten sin-aaltojen summana
