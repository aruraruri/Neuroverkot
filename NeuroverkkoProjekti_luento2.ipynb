# %% [markdown]
# # Convolutional Neural Networks / CNN

# %% [markdown]
# Erona FCN verkkoihin, inputteja ei koskaan vedetä 1D vektoriksi.
#
# Iso valikoima 3x3 filttereitä/kerneleitä, joita koulutetaan back-propagation algoritmilla.
#
# Conv2D, kaksiulotteinen konvoluutiokerros. Yksi filtteri käy läpi kuvaa pikseli kerrallaan. Kuvat seuraavassa kerroksessa ovat pienempiä, nämä siirtyvät verkon läpi.

# %%
import keras
from keras import layers

import numpy as np
import matplotlib.pyplot as plt

# %%
from keras import backend as K

# %%
num_classes = 10
# 1 is one grayscale channel, 3 if rgb
input_shape = (28, 28, 1)

# %%
# adding the grayscale channel to (28, 28)
np.expand_dims(x_train, -1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.expand_dims(x_train, -1)
#
# NameError: name 'np' is not defined

# %% [markdown]
# MaxPooling2D, local maximum of pixel values, trying to find features.
#
# Last layers are fully connected
