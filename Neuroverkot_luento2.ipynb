# %%
from keras.models import Sequential
# 'to categorical' is used to transform dataset target whole numbers into one-hot encoded array with other target categories as 0 and corresponding value as 1 for ex.
# [0, 0, 0, 0, 0, 1, 0, 0]

# flatten() mallin määrittelyssä tekee inputista yksiulotteisen

# ennen mallin koulutusta pitää ajaa compile, jossa määritellään optimizer (erillinen koodipätkä: hoitaa kustannusfunktion minimoinnin yksityiskohdat), kustannusfunktio (vakiintuneet funktiot tiettyihin luokittelutilanteisiin)

# batch=32, otetaan 32 havaintoa, lasketaan ennusteet, verrataan 32:een oikeaan arvoon. batch valitaan randomisti koko input setistä. parametrien säätö tapahtuu aina batchin jälkeen.

# model.summary() listaa parametrimäärät
# rmsprop optimizer tuplaa parametrimäärät

# yks epoch on koko koulutusjoukon läpikäynti

# fit runaaminen uudestaan vaan jatkaa mallin koulutusta jos ei modelia tehdä uudestaan

# evaluate testaamiseen

# predict
